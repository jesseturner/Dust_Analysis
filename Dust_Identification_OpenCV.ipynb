# %% [markdown]
# ### Using OpenCV computer vision to attempt to identify dust plumes

# %% [markdown]
# *Videos are made with images generated in Dust_Identification.ipynb*

# %%
import cv2 as cv 
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# Load the video
cap = cv.VideoCapture('Dust_Identification_Cases/2024_01_08/animation.mp4')

# Create a Background Subtractor object
fgbg = cv.createBackgroundSubtractorMOG2()

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
ax.axis('off')  # Turn off axis for better visualization

# Initialize the first frame (we'll update this frame in the animation)
frame_rgb = None

# Function to update the plot for each frame
def update_frame(frame_idx):
    global frame_rgb
    ret, frame = cap.read()
    if not ret:
        return None

    # Apply the background subtractor to get the foreground mask
    fgmask = fgbg.apply(frame)

    # Perform some morphological operations to clean up the mask
    kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 5))
    fgmask = cv.morphologyEx(fgmask, cv.MORPH_CLOSE, kernel)

    # Find contours of the moving parts
    contours, _ = cv.findContours(fgmask, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

    # Draw contours around the moving parts
    for contour in contours:
        if cv.contourArea(contour) > 500:  # Filter small contours
            x, y, w, h = cv.boundingRect(contour)
            cv.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Convert frame from BGR to RGB for Matplotlib
    frame_rgb = cv.cvtColor(frame, cv.COLOR_BGR2RGB)

    # Display the frame
    ax.imshow(frame_rgb)
    return [ax.imshow(frame_rgb)]

# Create the animation
ani = FuncAnimation(fig, update_frame, frames=500, interval=50, blit=True)

# Save the animation as a .gif
ani.save('Dust_Identification_Cases/2024_01_08/animation_OpenCV.gif', writer='imagemagick', fps=3)

# Release the video capture object and close the plot
cap.release()
plt.close()
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 48
#      45 ani = FuncAnimation(fig, update_frame, frames=500, interval=50, blit=True)
#      47 # Save the animation as a .gif
# ---> 48 ani.save('Dust_Identification_Cases/2024_01_08/animation_OpenCV.gif', writer='imagemagick', fps=3)
#      50 # Release the video capture object and close the plot
#      51 cap.release()
#
# File /Applications/anaconda3/envs/flc_local/lib/python3.12/site-packages/matplotlib/animation.py:1085, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1082 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1083     for anim, d in zip(all_anim, data):
#    1084         # TODO: See if turning off blit is really necessary
# -> 1085         anim._draw_next_frame(d, blit=False)
#    1086         if progress_callback is not None:
#    1087             progress_callback(frame_number, total_frames)
#
# File /Applications/anaconda3/envs/flc_local/lib/python3.12/site-packages/matplotlib/animation.py:1120, in Animation._draw_next_frame(self, framedata, blit)
#    1116 def _draw_next_frame(self, framedata, blit):
#    1117     # Breaks down the drawing of the next frame into steps of pre- and
#    1118     # post- draw, as well as the drawing of the frame itself.
#    1119     self._pre_draw(framedata, blit)
# -> 1120     self._draw_frame(framedata)
#    1121     self._post_draw(framedata, blit)
#
# File /Applications/anaconda3/envs/flc_local/lib/python3.12/site-packages/matplotlib/animation.py:1756, in FuncAnimation._draw_frame(self, framedata)
#    1754     iter(self._drawn_artists)
#    1755 except TypeError:
# -> 1756     raise err from None
#    1758 # check each item if it's artist
#    1759 for i in self._drawn_artists:
#
# RuntimeError: The animation function must return a sequence of Artist objects.
